# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('ActivationDataset.csv')  
x = df['input'].values

# %%
df
# Out:
#        input
# 0   -5.00000
# 1   -4.97996
# 2   -4.95992
# 3   -4.93988
# 4   -4.91984
# ..       ...
# 495  4.91984
# 496  4.93988
# 497  4.95992
# 498  4.97996
# 499  5.00000
#
# [500 rows x 1 columns]

# %%
def plot(func, yaxis=(-1.4, 1.4)):
    plt.ylim(yaxis)
    plt.axhline(lw=1, c='black')
    plt.axvline(lw=1, c='black')
    plt.grid(alpha=0.4, ls='-.')
    plt.plot(x, func(x), 'r-')
    plt.show()

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
plt.title('Sigmoid')
plot(sigmoid, yaxis=(-0.4, 1.4))

# %%
def tanh(x):
    return (np.exp(x) - np.exp(-x)) / (np.exp(x) + np.exp(-x))

# %%
plt.title('Tanh')
plot(tanh)

# %%
def relu(x):
    return np.maximum(0, x)

# %%
plt.title('ReLu')
plot(relu)

# %%
def leaky_relu(x):
    return np.maximum(0.1 * x, x)

# %%
plt.title('Leaky_ReLu')
plot(leaky_relu)
